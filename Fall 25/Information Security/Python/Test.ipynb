# %%
print("Test")
for i in range(26):
    odd = i%2
    if odd == 0:
        print(i*3)
print("End - Test")

# let's discuss about other basics of python
# Out:
# Test
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 66
# 72
# End - Test

# %% [markdown]
# # Testing
# - *python*
# - **md**

# %%
print("Next Cell")
# Out:
# Next Cell
