# %% [markdown]
# # files
# ## with statement
# 1. Handles errors and manages external resources
# 2. Python knows to automatically relsease resources taht would otherwise keep our system busy until the program finishes running.
# 3. Autometically close the file after reading it.
# 4. Syntex
#     with open("filename.txt/Link", "mentionHereWhatWantToDoWithThisFile - r/w/a etc.") as file:
#         file_text = file.read()
# .read() # this will convert the file into strings

# %%
# file reading 
with open("test.txt", "r") as file:
    file_text = file.read()
print(file_text)
print("test")
